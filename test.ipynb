# %%
from my_llm.ollama_client import ollama_chat

system_prompt = "You are a testing assistant."
user_prompt = "Reply with a short hello."

reply = ollama_chat(system_prompt, user_prompt, model="gemma3:270m")

print("\n📝 Ollama Reply:\n", reply)
# Out:
# 📝 Ollama Reply:
#  [Ollama Error] 'message'
